# %% [markdown]
# # **Conceptos Necesarios**
#
# $\hspace{0.5cm}$
#
# # Machine Learning
#
# El aprendizaje automático (ML) es un subconjunto de la inteligencia artificial (IA) que implica el uso de algoritmos y modelos estadísticos para permitir que las computadoras realicen tareas sin estar programadas explícitamente para realizarlas. Básicamente, permite a las computadoras aprender y hacer predicciones o decisiones basadas en datos. El proceso comienza alimentando a la computadora con una gran cantidad de datos, después de lo cual utiliza estos datos para aprender patrones y tendencias, que luego pueden usarse para hacer predicciones sobre datos nuevos e invisibles. Se utiliza ampliamente en diversos campos, incluidos, entre otros, análisis de datos, procesamiento de lenguaje natural, reconocimiento de imágenes y vehículos autónomos.

# %%
# !pip install pillow tensorflow numpy
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.13.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.57.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.33.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (3.2.2)

# %% [markdown]
# ## Preprocesamiento de las imagenes

# %%
from PIL import Image
import numpy as np
import glob

# Especificamos la ruta a las imágenes de color.
path_to_images = "/content/Colour/*"

# Inicializamos listas para almacenar imágenes, tanto las de escala de grises y las de color.
X_train = []
Y_train = []

for filename in glob.glob(path_to_images):
    with Image.open(filename) as img:
        # Cambia el tamaño de las imagenes a un tamaño fijo (en este caso, 256x256, incluso si ya tienen ese tamaño)
        img = img.resize((256, 256))

        # Convierte las imagenes a una matriz numpy y las normaliza
        img_array = np.array(img) / 255.0

        # Comprueba si tengo una imagen en escala de grises; de ser así, la convierte a RGB. (aunque no es lo que necesitamos, es solo una precaucion)
        if len(img_array.shape) == 2:
            img_array = np.stack([img_array]*3, axis=-1)

        # Si la imagen es RGBA, se convierte a RGB
        if img_array.shape[2] == 4:
            img_array = img_array[:, :, :3]

        # Creamos la versión en escala de grises de la imagen.
        gray_img_array = np.dot(img_array[...,:3], [0.2989, 0.5870, 0.1140])
        gray_img_array = gray_img_array.reshape(256, 256, 1)

        X_train.append(gray_img_array)
        Y_train.append(img_array)

# Convertimos las listas en arreglos de numpy
X_train = np.array(X_train)
Y_train = np.array(Y_train)

# %% [markdown]
# ## Entrenamiento de una pequeña red neuronal

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Input, Conv2D, UpSampling2D
from keras.models import Model

# Necesitamos crear un modelo simple similar a U-Net, que nos permite codificar una red neuronal sin mucho codigo.
def create_model(input_shape):
    input_img = Input(shape=input_shape)

    x = Conv2D(64, (3, 3), activation='relu', padding='same')(input_img)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', strides=2)(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', strides=2)(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)

    x = UpSampling2D((2, 2))(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

    model = Model(input_img, x)
    return model

# Nuestro modelo asume que las imágenes de entrada son imágenes en escala de grises de 256x256
model = create_model((256, 256, 1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Planteamos que X_train es el conjunto de imágenes en escala de grises y Y_train es el conjunto de imágenes de color correspondientes.
model.fit(X_train, Y_train, epochs=250, batch_size=64, validation_split=0.1)
# Out:
# Epoch 1/250
# 1/1 [==============================] - 42s 42s/step - loss: 0.0818 - val_loss: 0.0674
# Epoch 2/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0793 - val_loss: 0.0660
# Epoch 3/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0741 - val_loss: 0.0726
# Epoch 4/250
# 1/1 [==============================] - 37s 37s/step - loss: 0.0754 - val_loss: 0.0643
# Epoch 5/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0715 - val_loss: 0.0608
# Epoch 6/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0695 - val_loss: 0.0589
# Epoch 7/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0658 - val_loss: 0.0604
# Epoch 8/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0626 - val_loss: 0.0521
# Epoch 9/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0543 - val_loss: 0.0448
# Epoch 10/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0456 - val_loss: 0.0430
# Epoch 11/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0391 - val_loss: 0.0346
# Epoch 12/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0341 - val_loss: 0.0322
# Epoch 13/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0310 - val_loss: 0.0366
# Epoch 14/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0352 - val_loss: 0.0335
# Epoch 15/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0333 - val_loss: 0.0347
# Epoch 16/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0348 - val_loss: 0.0317
# Epoch 17/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0313 - val_loss: 0.0339
# Epoch 18/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0328 - val_loss: 0.0294
# Epoch 19/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0280 - val_loss: 0.0314
# Epoch 20/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0298 - val_loss: 0.0285
# Epoch 21/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0259 - val_loss: 0.0308
# Epoch 22/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0277 - val_loss: 0.0278
# Epoch 23/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0253 - val_loss: 0.0257
# Epoch 24/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0234 - val_loss: 0.0246
# Epoch 25/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0236 - val_loss: 0.0215
# Epoch 26/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0207 - val_loss: 0.0242
# Epoch 27/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0224 - val_loss: 0.0197
# Epoch 28/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0196 - val_loss: 0.0207
# Epoch 29/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0206 - val_loss: 0.0207
# Epoch 30/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0203 - val_loss: 0.0180
# Epoch 31/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0180 - val_loss: 0.0204
# Epoch 32/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0196 - val_loss: 0.0199
# Epoch 33/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0191 - val_loss: 0.0173
# Epoch 34/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0166 - val_loss: 0.0184
# Epoch 35/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0172 - val_loss: 0.0193
# Epoch 36/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0183 - val_loss: 0.0176
# Epoch 37/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0164 - val_loss: 0.0167
# Epoch 38/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0159 - val_loss: 0.0174
# Epoch 39/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0170 - val_loss: 0.0162
# Epoch 40/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0158 - val_loss: 0.0161
# Epoch 41/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0158 - val_loss: 0.0163
# Epoch 42/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0163 - val_loss: 0.0153
# Epoch 43/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0152 - val_loss: 0.0159
# Epoch 44/250
# 1/1 [==============================] - 37s 37s/step - loss: 0.0156 - val_loss: 0.0157
# Epoch 45/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0156 - val_loss: 0.0151
# Epoch 46/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0148 - val_loss: 0.0158
# Epoch 47/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0152 - val_loss: 0.0156
# Epoch 48/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0152 - val_loss: 0.0152
# Epoch 49/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0146 - val_loss: 0.0152
# Epoch 50/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0146 - val_loss: 0.0152
# Epoch 51/250
# 1/1 [==============================] - 44s 44s/step - loss: 0.0149 - val_loss: 0.0152
# Epoch 52/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0147 - val_loss: 0.0145
# Epoch 53/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0142 - val_loss: 0.0144
# Epoch 54/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0142 - val_loss: 0.0148
# Epoch 55/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0145 - val_loss: 0.0144
# Epoch 56/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0143 - val_loss: 0.0141
# Epoch 57/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0139 - val_loss: 0.0140
# Epoch 58/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0138 - val_loss: 0.0142
# Epoch 59/250
# 1/1 [==============================] - 37s 37s/step - loss: 0.0139 - val_loss: 0.0146
# Epoch 60/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0142 - val_loss: 0.0148
# Epoch 61/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0144 - val_loss: 0.0148
# Epoch 62/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0143 - val_loss: 0.0139
# Epoch 63/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0137 - val_loss: 0.0136
# Epoch 64/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0133 - val_loss: 0.0139
# Epoch 65/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0135 - val_loss: 0.0140
# Epoch 66/250
# 1/1 [==============================] - 47s 47s/step - loss: 0.0138 - val_loss: 0.0140
# Epoch 67/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0137 - val_loss: 0.0134
# Epoch 68/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0132 - val_loss: 0.0132
# Epoch 69/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0130 - val_loss: 0.0135
# Epoch 70/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0132 - val_loss: 0.0136
# Epoch 71/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0134 - val_loss: 0.0139
# Epoch 72/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0135 - val_loss: 0.0135
# Epoch 73/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0133 - val_loss: 0.0132
# Epoch 74/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0130 - val_loss: 0.0128
# Epoch 75/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0127 - val_loss: 0.0127
# Epoch 76/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0126 - val_loss: 0.0129
# Epoch 77/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0128 - val_loss: 0.0132
# Epoch 78/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0131 - val_loss: 0.0141
# Epoch 79/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0137 - val_loss: 0.0139
# Epoch 80/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0138 - val_loss: 0.0132
# Epoch 81/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0130 - val_loss: 0.0125
# Epoch 82/250
# 1/1 [==============================] - 44s 44s/step - loss: 0.0123 - val_loss: 0.0130
# Epoch 83/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0129 - val_loss: 0.0134
# Epoch 84/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0131 - val_loss: 0.0124
# Epoch 85/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0123 - val_loss: 0.0125
# Epoch 86/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0124 - val_loss: 0.0131
# Epoch 87/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0128 - val_loss: 0.0125
# Epoch 88/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0123 - val_loss: 0.0122
# Epoch 89/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0121 - val_loss: 0.0126
# Epoch 90/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0124 - val_loss: 0.0125
# Epoch 91/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0125 - val_loss: 0.0123
# Epoch 92/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0121 - val_loss: 0.0121
# Epoch 93/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0119 - val_loss: 0.0122
# Epoch 94/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0121 - val_loss: 0.0124
# Epoch 95/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0122 - val_loss: 0.0121
# Epoch 96/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0120 - val_loss: 0.0119
# Epoch 97/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0118 - val_loss: 0.0119
# Epoch 98/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0117 - val_loss: 0.0120
# Epoch 99/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0119 - val_loss: 0.0123
# Epoch 100/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0120 - val_loss: 0.0122
# Epoch 101/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0121 - val_loss: 0.0124
# Epoch 102/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0121 - val_loss: 0.0120
# Epoch 103/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0119 - val_loss: 0.0118
# Epoch 104/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0117 - val_loss: 0.0116
# Epoch 105/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0115 - val_loss: 0.0116
# Epoch 106/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 107/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0117 - val_loss: 0.0119
# Epoch 108/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0118 - val_loss: 0.0121
# Epoch 109/250
# 1/1 [==============================] - 37s 37s/step - loss: 0.0119 - val_loss: 0.0119
# Epoch 110/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0118 - val_loss: 0.0118
# Epoch 111/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0116 - val_loss: 0.0115
# Epoch 112/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0114 - val_loss: 0.0114
# Epoch 113/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0112 - val_loss: 0.0114
# Epoch 114/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0112 - val_loss: 0.0114
# Epoch 115/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 116/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 117/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0116 - val_loss: 0.0125
# Epoch 118/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0122 - val_loss: 0.0130
# Epoch 119/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0128 - val_loss: 0.0133
# Epoch 120/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0129 - val_loss: 0.0115
# Epoch 121/250
# 1/1 [==============================] - 37s 37s/step - loss: 0.0115 - val_loss: 0.0112
# Epoch 122/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0113 - val_loss: 0.0123
# Epoch 123/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0122 - val_loss: 0.0114
# Epoch 124/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0115 - val_loss: 0.0112
# Epoch 125/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0111 - val_loss: 0.0120
# Epoch 126/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0117 - val_loss: 0.0114
# Epoch 127/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0112 - val_loss: 0.0111
# Epoch 128/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0110 - val_loss: 0.0116
# Epoch 129/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0114 - val_loss: 0.0114
# Epoch 130/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0112 - val_loss: 0.0111
# Epoch 131/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 132/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 133/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0111 - val_loss: 0.0110
# Epoch 134/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0108 - val_loss: 0.0109
# Epoch 135/250
# 1/1 [==============================] - 37s 37s/step - loss: 0.0107 - val_loss: 0.0110
# Epoch 136/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0109 - val_loss: 0.0112
# Epoch 137/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0109 - val_loss: 0.0108
# Epoch 138/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0107 - val_loss: 0.0107
# Epoch 139/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 140/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0106 - val_loss: 0.0109
# Epoch 141/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0107 - val_loss: 0.0114
# Epoch 142/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 143/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0111 - val_loss: 0.0110
# Epoch 144/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0108 - val_loss: 0.0105
# Epoch 145/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 146/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0105 - val_loss: 0.0111
# Epoch 147/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 148/250
# 1/1 [==============================] - 37s 37s/step - loss: 0.0108 - val_loss: 0.0108
# Epoch 149/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0106 - val_loss: 0.0104
# Epoch 150/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0103 - val_loss: 0.0104
# Epoch 151/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0103 - val_loss: 0.0107
# Epoch 152/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 153/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0105 - val_loss: 0.0109
# Epoch 154/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0106 - val_loss: 0.0105
# Epoch 155/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0105 - val_loss: 0.0104
# Epoch 156/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0102 - val_loss: 0.0102
# Epoch 157/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0101 - val_loss: 0.0104
# Epoch 158/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0101 - val_loss: 0.0107
# Epoch 159/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0104 - val_loss: 0.0108
# Epoch 160/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0108 - val_loss: 0.0120
# Epoch 161/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0115 - val_loss: 0.0109
# Epoch 162/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0108 - val_loss: 0.0100
# Epoch 163/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 164/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0102 - val_loss: 0.0112
# Epoch 165/250
# 1/1 [==============================] - 42s 42s/step - loss: 0.0107 - val_loss: 0.0106
# Epoch 166/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0106 - val_loss: 0.0101
# Epoch 167/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0100 - val_loss: 0.0105
# Epoch 168/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0100 - val_loss: 0.0107
# Epoch 169/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0103 - val_loss: 0.0103
# Epoch 170/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0103 - val_loss: 0.0109
# Epoch 171/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0101 - val_loss: 0.0101
# Epoch 172/250
# 1/1 [==============================] - 42s 42s/step - loss: 0.0098 - val_loss: 0.0097
# Epoch 173/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0100 - val_loss: 0.0104
# Epoch 174/250
# 1/1 [==============================] - 42s 42s/step - loss: 0.0100 - val_loss: 0.0108
# Epoch 175/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0100 - val_loss: 0.0100
# Epoch 176/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0098 - val_loss: 0.0098
# Epoch 177/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0097 - val_loss: 0.0105
# Epoch 178/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0097 - val_loss: 0.0104
# Epoch 179/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 180/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0098 - val_loss: 0.0105
# Epoch 181/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0098 - val_loss: 0.0104
# Epoch 182/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0099 - val_loss: 0.0099
# Epoch 183/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0097 - val_loss: 0.0097
# Epoch 184/250
# 1/1 [==============================] - 42s 42s/step - loss: 0.0095 - val_loss: 0.0104
# Epoch 185/250
# 1/1 [==============================] - 42s 42s/step - loss: 0.0096 - val_loss: 0.0103
# Epoch 186/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 187/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0100 - val_loss: 0.0114
# Epoch 188/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0103 - val_loss: 0.0104
# Epoch 189/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 190/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0095 - val_loss: 0.0099
# Epoch 191/250
# 1/1 [==============================] - 43s 43s/step - loss: 0.0094 - val_loss: 0.0105
# Epoch 192/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0097 - val_loss: 0.0106
# Epoch 193/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0100 - val_loss: 0.0099
# Epoch 194/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0099 - val_loss: 0.0104
# Epoch 195/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0094 - val_loss: 0.0104
# Epoch 196/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0094 - val_loss: 0.0100
# Epoch 197/250
# 1/1 [==============================] - 42s 42s/step - loss: 0.0097 - val_loss: 0.0106
# Epoch 198/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0099 - val_loss: 0.0104
# Epoch 199/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 200/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0092 - val_loss: 0.0101
# Epoch 201/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0094 - val_loss: 0.0107
# Epoch 202/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0097 - val_loss: 0.0106
# Epoch 203/250
# 1/1 [==============================] - 44s 44s/step - loss: 0.0098 - val_loss: 0.0096
# Epoch 204/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0094 - val_loss: 0.0101
# Epoch 205/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0092 - val_loss: 0.0106
# Epoch 206/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0095 - val_loss: 0.0103
# Epoch 207/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0099 - val_loss: 0.0113
# Epoch 208/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0098 - val_loss: 0.0098
# Epoch 209/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0093 - val_loss: 0.0096
# Epoch 210/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0094 - val_loss: 0.0105
# Epoch 211/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0096 - val_loss: 0.0105
# Epoch 212/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0094 - val_loss: 0.0097
# Epoch 213/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0090 - val_loss: 0.0099
# Epoch 214/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0091 - val_loss: 0.0102
# Epoch 215/250
# 1/1 [==============================] - 42s 42s/step - loss: 0.0092 - val_loss: 0.0097
# Epoch 216/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0089 - val_loss: 0.0097
# Epoch 217/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0089 - val_loss: 0.0102
# Epoch 218/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0090 - val_loss: 0.0100
# Epoch 219/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0090 - val_loss: 0.0099
# Epoch 220/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0090 - val_loss: 0.0106
# Epoch 221/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0089 - val_loss: 0.0095
# Epoch 222/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0089 - val_loss: 0.0101
# Epoch 223/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0087 - val_loss: 0.0101
# Epoch 224/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0087 - val_loss: 0.0094
# Epoch 225/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0087 - val_loss: 0.0102
# Epoch 226/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0087 - val_loss: 0.0098
# Epoch 227/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0087 - val_loss: 0.0099
# Epoch 228/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0088 - val_loss: 0.0101
# Epoch 229/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0090 - val_loss: 0.0110
# Epoch 230/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0093 - val_loss: 0.0101
# Epoch 231/250
# 1/1 [==============================] - 37s 37s/step - loss: 0.0097 - val_loss: 0.0124
# Epoch 232/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0100 - val_loss: 0.0100
# Epoch 233/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0090 - val_loss: 0.0092
# Epoch 234/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0088 - val_loss: 0.0103
# Epoch 235/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0091 - val_loss: 0.0107
# Epoch 236/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 237/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0088 - val_loss: 0.0095
# Epoch 238/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0086 - val_loss: 0.0105
# Epoch 239/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0090 - val_loss: 0.0103
# Epoch 240/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0090 - val_loss: 0.0094
# Epoch 241/250
# 1/1 [==============================] - 41s 41s/step - loss: 0.0086 - val_loss: 0.0097
# Epoch 242/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0086 - val_loss: 0.0106
# Epoch 243/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0089 - val_loss: 0.0099
# Epoch 244/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0085 - val_loss: 0.0094
# Epoch 245/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0084 - val_loss: 0.0100
# Epoch 246/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0086 - val_loss: 0.0101
# Epoch 247/250
# 1/1 [==============================] - 40s 40s/step - loss: 0.0085 - val_loss: 0.0095
# Epoch 248/250
# 1/1 [==============================] - 37s 37s/step - loss: 0.0083 - val_loss: 0.0096
# Epoch 249/250
# 1/1 [==============================] - 38s 38s/step - loss: 0.0084 - val_loss: 0.0101
# Epoch 250/250
# 1/1 [==============================] - 39s 39s/step - loss: 0.0085 - val_loss: 0.0099

# %%
import matplotlib.pyplot as plt

# Choose a few test images (grayscale)
test_images = X_train[:5]

# Get the model's colorized versions of the test images
colorized_images = model.predict(test_images)

# Convert grayscale test images to RGB for visualization
test_images_rgb = [np.squeeze(np.stack([img]*3, axis=-1)) for img in test_images]

# Plot the original, grayscale, and colorized images side by side
for i in range(len(test_images)):
    plt.figure(figsize=(10, 4))

    plt.subplot(1, 3, 1)
    plt.imshow(Y_train[i])
    plt.title("Original")
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.imshow(test_images_rgb[i], cmap='gray')
    plt.title("Grayscale")
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.imshow(colorized_images[i])
    plt.title("Colorized")
    plt.axis('off')

    plt.tight_layout()
    plt.show()
# Out:
# 1/1 [==============================] - 4s 4s/step
